# %%
import pandas as pd

# %%
df=pd.read_csv("imdb_top_1000.csv")

# %%
df["Released_Year"]=df["Released_Year"].str.replace(")","0")

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df['Released_Year'].unique()
# Out:
# <ArrowStringArray>
# ['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010', '1999',
#  '2001', '1966', '2002', '1990', '1980', '1975', '2020', '2019', '2014',
#  '1998', '1997', '1995', '1991', '1977', '1962', '1954', '1946', '2011',
#  '2006', '2000', '1988', '1985', '1968', '1960', '1942', '1936', '1931',
#  '2018', '2017', '2016', '2012', '2009', '2007', '1984', '1981', '1979',
#  '1971', '1963', '1964', '1950', '1940', '2013', '2005', '2004', '1992',
#  '1987', '1986', '1983', '1976', '1973', '1965', '1959', '1958', '1952',
#  '1948', '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#  '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951', '1949',
#  '1939', '1937', '1934', '1928', '1926', '1920', '1970', '1969', '1956',
#  '1947', '1945', '1930', '1938', '1935', '1933', '1932', '1922', '1943',
#    'PG']
# Length: 100, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   str
#  1   Series_Title   1000 non-null   str
#  2   Released_Year  1000 non-null   str
#  3   Certificate    899 non-null    str
#  4   Runtime        1000 non-null   str
#  5   Genre          1000 non-null   str
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   str
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   str
#  10  Star1          1000 non-null   str
#  11  Star2          1000 non-null   str
#  12  Star3          1000 non-null   str
#  13  Star4          1000 non-null   str
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    str
# dtypes: float64(2), int64(1), str(13)
# memory usage: 520.7 KB

# %%
gross_sum=df.groupby("Certificate")["Gross"].sum()
print(gross_sum)
# Out:
# Certificate
# 16
# A           2,83,41,46913,49,66,4115,73,00,00010,79,28,762...
# Approved    39,69,8934,49,19143,60,00043,60,0002,36,50,000...
# G           1,63,24519,18188,19,0281,77,34521,89,67,6208,0...
# GP                                            39,48113,78,435
# PG          9,33,93312,29,1978,57,52426,03,0614,49,08,0002...
# PG-13       70,98,49214,98,2102,35,30,89244,45,75659,90,07...
# Passed      2,88,47557,20,00028,87754,50,00010,17750,14,00...
# R           21,65,40,9093,25,72,57767,19,8648,34,71,5117,8...
# TV-14
# TV-MA
# TV-PG                                                1,06,662
# U           43,60,00037,78,45,90531,55,44,7501,00,55,8595,...
# U/A                                               2,60,20,957
# UA          53,48,58,44429,25,76,19533,02,52,18234,25,51,3...
# Unrated                                              3,00,000
# Name: Gross, dtype: str

# %%
gross_sum2=df.groupby("Certificate")["Gross"].agg(["min","max"])
print(gross_sum2)
# Out:
#                      min          max
# Certificate
# 16                   NaN          NaN
# A            1,12,86,112    96,00,000
# Approved     2,36,50,000    49,05,000
# G               1,63,245    88,19,028
# GP             13,78,435       39,481
# PG           1,17,98,616    94,50,000
# PG-13        1,03,01,706    94,22,422
# Passed       1,00,00,000    96,00,000
# R            1,00,95,170    94,39,923
# TV-14                NaN          NaN
# TV-MA                NaN          NaN
# TV-PG           1,06,662     1,06,662
# U            1,00,19,307    99,29,135
# U/A          2,60,20,957  2,60,20,957
# UA           1,06,00,000     9,85,912
# Unrated         3,00,000     3,00,000

# %%
df["Gross"]=df["Gross"].str.replace(",","")

# %%
df["Gross"].isna().sum()
# Out:
# np.int64(169)

# %%
df["Gross"]=df["Gross"].fillna(0)

# %%
df["Gross"]=df["Gross"].astype('int')

# %%
df["Gross"].isna().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gross, Length: 1000, dtype: bool>

# %%
df.groupby('Certificate')["Gross"].agg(["min", "max"])
# Out:
#                   min        max
# Certificate
# 16                  0          0
# A                   0  335451311
# Approved            0   23650000
# G                   0  218967620
# GP              39481    1378435
# PG                  0  102308889
# PG-13               0  209028679
# Passed              0   30500000
# R                   0  363070709
# TV-14               0          0
# TV-MA               0          0
# TV-PG               0     106662
# U                   0  936662225
# U/A          26020957   26020957
# UA                  0  858373000
# Unrated        300000     300000

# %%
df.sort_values(["Released_Year"])
# Out:
#                                            Poster_Link  \
# 321  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 568  https://m.media-amazon.com/images/M/MV5BMTAxYj...
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 193  https://m.media-amazon.com/images/M/MV5BZjEyOT...
# ..                                                 ...
# 205  https://m.media-amazon.com/images/M/MV5BZGE1MD...
# 464  https://m.media-amazon.com/images/M/MV5BNmI0MT...
# 612  https://m.media-amazon.com/images/M/MV5BYjYzOG...
# 613  https://m.media-amazon.com/images/M/MV5BOTNjM2...
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
#
#                      Series_Title Released_Year Certificate  Runtime  \
# 321  Das Cabinet des Dr. Caligari          1920         NaN   76 min
# 127                       The Kid          1921      Passed   68 min
# 568                     Nosferatu          1922         NaN   94 min
# ...

# %%
df["Released_Year"].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df['Released_Year'] = df['Released_Year'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['Released_Year'] = df['Released_Year'].astype(int)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
# ...

# %%
df_direc_time=

# %%
df_direc_time["active"]=df_direc_time['max']-df_direc_time['min']
df_direc_time.sort_values(by='active',ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_direc_time["active"]=df_direc_time['max']-df_direc_time['min']
#       2 df_direc_time.sort_values(by='active',ascending=False).head()
#
# NameError: name 'df_direc_time' is not defined

# %%
df_direc_time=df.groupby("Director")["Released_Year"].agg(["mean", "max"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_direc_time=df.groupby("Director")["Released_Year"].agg(["mean", "max"])
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:464, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     462 kwargs["engine"] = engine
#     463 kwargs["engine_kwargs"] = engine_kwargs
# --> 464 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     465 if relabeling:
#     466     # columns is not narrowed by mypy from relabeling flag
#     467     assert columns is not None  # for mypy
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:522, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
# ...

# %%
df_dir_bud["Gross"]=df_dir_bud['Gross']/1000000
df_dir_bud["Gross"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df_dir_bud["Gross"]=df_dir_bud['Gross']/1000000
#       2 df_dir_bud["Gross"]
#
# NameError: name 'df_dir_bud' is not defined
