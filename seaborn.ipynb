# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
    "Employee_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Department": ["IT", "HR", "IT", "Sales", "HR", "IT", "Sales", "IT", "Marketing", "HR"],
    "Gender": ["Male", "Female", "Male", "Female", "Female", "Male", "Male", "Female", "Male", "Female"],
    "Age": [25, 30, 28, 35, 27, 32, 29, 26, 31, 33],
    "Salary": [45000, 52000, 48000, 60000, 50000, 70000, 55000, 47000, 62000, 58000],
    "Experience": [2, 5, 3, 8, 4, 9, 6, 2, 7, 5]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Employee_ID Department  Gender  Age  Salary  Experience
# 0          101         IT    Male   25   45000           2
# 1          102         HR  Female   30   52000           5
# 2          103         IT    Male   28   48000           3
# 3          104      Sales  Female   35   60000           8
# 4          105         HR  Female   27   50000           4
# 5          106         IT    Male   32   70000           9
# 6          107      Sales    Male   29   55000           6
# 7          108         IT  Female   26   47000           2
# 8          109  Marketing    Male   31   62000           7
# 9          110         HR  Female   33   58000           5

# %%
sns.countplot(data=df, x="Department")
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
df["Department"].count()
# Out:
# np.int64(10)

# %%
df["Department"].value_counts()
# Out:
# Department
# IT           4
# HR           3
# Sales        2
# Marketing    1
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Assuming df is already created

sns.countplot(data=df, x="Department")
plt.show()
