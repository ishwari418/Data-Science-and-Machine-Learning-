# %% [markdown]
# List

# %%
colors = ["Red", "Blue", "Green", "Black"]
print(colors[1])
# Out:
# Blue

# %%
fruits=["Apple","Mangoes"]
fruits.append("orange")
print(fruits)
# Out:
# ['Apple', 'Mangoes', 'orange']

# %%
fruits = ["Apple", "Orange"]

fruits.insert(0, "Banana")

print(fruits)
# Out:
# ['Banana', 'Apple', 'Orange']

# %%
fruits = ["Apple", "Orange"]

fruits.insert(1, "Banana")

print(fruits)
# Out:
# ['Apple', 'Banana', 'Orange']

# %%
fruits = ["Apple", "Banana", "Orange"]

fruits.remove("Banana")

print(fruits)
# Out:
# ['Apple', 'Orange']

# %% [markdown]
# Slicing

# %%
numbers=[23,65,44,55,33,876,22]
print(numbers[:3])
# Out:
# [23, 65, 44]

# %%
numbers=[23,65,44,55,33,876,22]
print (numbers[::-1])
print(numbers[1:4])
print (numbers[::-2])
print (numbers[2:])
print(numbers[-3::])
print(len(numbers))
# Out:
# [22, 876, 33, 55, 44, 65, 23]
# [65, 44, 55]
# [22, 33, 44, 23]
# [44, 55, 33, 876, 22]
# [33, 876, 22]
# 7

# %% [markdown]
# **Tuple**

# %%
fruits = ("Apple", "Banana", "Orange")
print(fruits[2])
# Out:
# Orange

# %%
'''list
Create a list of 5 fruits and print the third fruit.
Add "Kiwi" to the end.
Insert "Grapes" at index 2.
Remove "Apple" (if it exists).
Print the length of the list.
Print only the last three fruits using slicing.'''

fruits=["orange","mangoes","apple","banana","pineapple"]
fruits.append("Kiwi")
fruits.insert(2,"Grapes")
fruits.remove("apple")
print(len(fruits))
print(fruits[-3:])   #last three fruits
# Out:
# 6
# ['banana', 'pineapple', 'Kiwi']

# %%
'''Part B – Tuples
Create a tuple of 5 numbers.
Print the first and last number.
Try changing one value. What error do you get?
Use len() to print the size of the tuple.'''

tuple=(3,4,5,8,6,7)
print(tuple[0])
print(tuple[-1])
print(len(tuple))
# Out:
# 3
# 7
# 6

# %%
a = [1, 2]
b = [3, 4]

a.extend(b)

print(a)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Distonary and Keys

# %%
student = {
    "name":"Ishwari",
    "age":20,
    "branch":"AIML",
    "cgpa":7.3
}
print(student["name"])
# Out:
# Ishwari

# %%
student["cgpa"]=8.0
student["city"]="pune"
student.pop("age")

print(student)
# Out:
# {'name': 'Ishwari', 'branch': 'AIML', 'cgpa': 8.0, 'city': 'pune'}

# %%
student.items()
# Out:
# dict_items([('name', 'Ishwari'), ('branch', 'AIML'), ('cgpa', 8.0), ('city', 'pune')])

# %%
#sets duplicates dissapear
numbers={1,5,2,3,1,7,5}
numbers.add(32)
numbers.remove(2)


print(numbers)
# Out:
# {32, 1, 3, 5, 7}

# %%
numbers={2,4,4,5,5,5,6}

print(numbers)
# Out:
# {2, 4, 5, 6}

# %%
numbers={1,2,3}

numbers.add(4)

print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
numbers = {1,2,3}

print(numbers[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 numbers = {1,2,3}
#       2
# ----> 3 print(numbers[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Functions

# %%
def greet():
    print("Hello")
greet()
# Out:
# Hello

# %%
def message():
    print("Good Morning")

message()
# Out:
# Good Morning

# %%
def greet(name):
    print("Hello", name)

greet("ishwari")
# Out:
# Hello ishwari

# %%
def country(name):
    print("Welcome to", name)

country("India")
country("Japan")
# Out:
# Welcome to India
# Welcome to Japan

# %%
def add(a, b):
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
def student(name, age):
    print(name)
    print(age)

student("Ishwari", 20)
# Out:
# Ishwari
# 20

# %%
def add(a, b):
    print(a + b)

result = add(10, 20)
print(result)
# Out:
# 30
# None

# %%
def add(a, b):
    return a + b
result = add(10, 20)

print(result)
# Out:
# 30

# %%
def calculate_average(numbers):
    total = 0

    for num in numbers:
        total += num

    return total / len(numbers)
print()
